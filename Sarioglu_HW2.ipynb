# %% [markdown]
# <a href="https://colab.research.google.com/github/EceSarioglu/BME3053C-Spring-2025/blob/main/Sarioglu_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bp_readings = [120, 137, 151, 123, 162, 173, 127, 154]

def normalize_value(reading):
  min_value = min(reading)
  max_value = max(reading)

  normalized = []

  for x in reading:
    normalized_value = (x-min_value)/(max_value-min_value)
    normalized_value = round(normalized_value, 3)
    normalized.append(normalized_value)

  return normalized

normalized_bp_readings = normalize_value(bp_readings)
print(normalized_bp_readings)
# Out:
# [0.0, 0.321, 0.585, 0.057, 0.792, 1.0, 0.132, 0.642]
